# %%
import requests
url='https://api.github.com/repos/pandas-dev/pandas/issues'
resp=requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data=resp.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43679',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43679/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43679/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43679/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43679',
#   'id': 1001769456,
#   'node_id': 'PR_kwDOAA0YD84sAM3U',
#   'number': 43679,
#   'title': 'REF: unify i8 casting in DatetimeEngine',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-21T03:33:06Z',
#   'updated_at': '2021-09-21T03:33:06Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43679',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43679',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43679.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43679.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43679/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43678',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43678/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43678/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43678/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43678',
#   'id': 1001672010,
#   'node_id': 'PR_kwDOAA0YD84r_48U',
#   'number': 43678,
#   'title': 'POC: New UDF methods option',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 35818298,
#     'node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#     'name': 'API Design',
#     'color': 'AD7FA8',
#     'default': False,
#     'description': None},
#    {'id': 697792067,
#     'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply',
#     'name': 'Apply',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Apply, Aggregate, Transform'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-21T01:59:24Z',
#   'updated_at': '2021-09-21T02:20:13Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43678',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43678',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43678.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43678.patch'},
#   'body': "Start of #41112\r\n\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [ ] whatsnew entry\r\n\r\nThe goal is to provide an implementation for apply on lists. See https://github.com/pandas-dev/pandas/issues/41112#issuecomment-902366002 for why this necessitates a change to agg behavior for lists. It is possible to break this up into several PRs, but wanted to give a view as to what it would appear in totality.\r\n\r\nAttached is a notebook demonstrating the differences in behavior (github doesn't allow attaching the notebook directly).\r\n\r\n[udfs.pdf](https://github.com/pandas-dev/pandas/files/7199652/udfs.pdf)\r\n\r\n",
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43678/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43677',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43677/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43677/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43677/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43677',
#   'id': 1001595729,
#   'node_id': 'PR_kwDOAA0YD84r_pa0',
#   'number': 43677,
#   'title': 'CI: Strict channel Priority',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
#    'followers_url': 'https://api.github.com/users/lithomas1/followers',
#    'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#    'repos_url': 'https://api.github.com/users/lithomas1/repos',
#    'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-21T00:23:04Z',
#   'updated_at': '2021-09-21T00:23:04Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43677',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43677',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43677.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43677.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43677/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43675',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43675/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43675/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43675/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43675',
#   'id': 1001529228,
#   'node_id': 'PR_kwDOAA0YD84r_bqa',
#   'number': 43675,
#   'title': 'PERF: Groupby.any/all object dtype',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-20T22:58:46Z',
#   'updated_at': '2021-09-21T03:37:27Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43675',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43675',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43675.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43675.patch'},
#   'body': '```\r\nfrom asv_bench.benchmarks.groupby import *\r\nself = GroupByMethods()\r\nself.setup("object", "any", "direct", 10)\r\n \r\n\r\n%timeit self.time_dtype_as_field("object", "any", "direct", 10)\r\n1.12 ms ± 60.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)  # <- PR\r\n11.4 ms ± 49.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)   # <- master\r\n```',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43675/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43674',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43674/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43674/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43674/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43674',
#   'id': 1001369179,
#   'node_id': 'PR_kwDOAA0YD84r-5Vl',
#   'number': 43674,
#   'title': 'GH 38815',
#   'user': {'login': 'horaceklai',
#    'id': 44500643,
#    'node_id': 'MDQ6VXNlcjQ0NTAwNjQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44500643?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/horaceklai',
#    'html_url': 'https://github.com/horaceklai',
#    'followers_url': 'https://api.github.com/users/horaceklai/followers',
#    'following_url': 'https://api.github.com/users/horaceklai/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/horaceklai/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/horaceklai/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/horaceklai/subscriptions',
#    'organizations_url': 'https://api.github.com/users/horaceklai/orgs',
#    'repos_url': 'https://api.github.com/users/horaceklai/repos',
#    'events_url': 'https://api.github.com/users/horaceklai/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/horaceklai/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-20T20:23:30Z',
#   'updated_at': '2021-09-20T20:48:44Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43674',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43674',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43674.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43674.patch'},
#   'body': 'Add more aggregation functions for nuisance tests\r\n\r\n- [ x] closes #38815\r\n- [x ] tests added / passed\r\n- [x ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43674/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43673',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43673/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43673/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43673/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43673',
#   'id': 1001318271,
#   'node_id': 'PR_kwDOAA0YD84r-u8T',
#   'number': 43673,
#   'title': 'ENH: omit CSSStyle rules for hidden table elements (#43619)',
#   'user': {'login': 'rendner',
#    'id': 414652,
#    'node_id': 'MDQ6VXNlcjQxNDY1Mg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/414652?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rendner',
#    'html_url': 'https://github.com/rendner',
#    'followers_url': 'https://api.github.com/users/rendner/followers',
#    'following_url': 'https://api.github.com/users/rendner/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rendner/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rendner/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rendner/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rendner/orgs',
#    'repos_url': 'https://api.github.com/users/rendner/repos',
#    'events_url': 'https://api.github.com/users/rendner/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rendner/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 1728592794,
#     'node_id': 'MDU6TGFiZWwxNzI4NTkyNzk0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Styler',
#     'name': 'Styler',
#     'color': '006b75',
#     'default': False,
#     'description': 'conditional formatting using DataFrame.style'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-09-20T19:25:30Z',
#   'updated_at': '2021-09-21T10:39:31Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43673',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43673',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43673.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43673.patch'},
#   'body': "- [x] closes #43619\r\n- [x] tests added / passed (but canceled due to another error)\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [x] whatsnew entry\r\n\r\nI couldn't run all tests, because of the following problem, which isn't related to my changes:\r\n```\r\npandas/tests/io/test_orc.py terminate called after throwing an instance of 'orc::TimezoneError'\r\n  what():  Can't open /etc/localtime\r\nFatal Python error: Aborted\r\n``` ",
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43673/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43672',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43672/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43672/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43672/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43672',
#   'id': 1001297490,
#   'node_id': 'PR_kwDOAA0YD84r-qzQ',
#   'number': 43672,
#   'title': 'CI: run pyright',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-20T19:03:24Z',
#   'updated_at': '2021-09-20T20:13:18Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43672',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43672',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43672.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43672.patch'},
#   'body': 'Run pyright in strict mode with a very long list of rules that need to be ignored.\r\n',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43672/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43671',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43671/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43671/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43671/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43671',
#   'id': 1001279065,
#   'node_id': 'PR_kwDOAA0YD84r-nVn',
#   'number': 43671,
#   'title': 'ENH: enable skipna on groupby reduction ops',
#   'user': {'login': 'geoffrey-eisenbarth',
#    'id': 8428345,
#    'node_id': 'MDQ6VXNlcjg0MjgzNDU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8428345?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/geoffrey-eisenbarth',
#    'html_url': 'https://github.com/geoffrey-eisenbarth',
#    'followers_url': 'https://api.github.com/users/geoffrey-eisenbarth/followers',
#    'following_url': 'https://api.github.com/users/geoffrey-eisenbarth/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/geoffrey-eisenbarth/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/geoffrey-eisenbarth/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/geoffrey-eisenbarth/subscriptions',
#    'organizations_url': 'https://api.github.com/users/geoffrey-eisenbarth/orgs',
#    'repos_url': 'https://api.github.com/users/geoffrey-eisenbarth/repos',
#    'events_url': 'https://api.github.com/users/geoffrey-eisenbarth/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/geoffrey-eisenbarth/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 2365504383,
#     'node_id': 'MDU6TGFiZWwyMzY1NTA0Mzgz',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reduction%20Operations',
#     'name': 'Reduction Operations',
#     'color': '547c03',
#     'default': False,
#     'description': 'sum, mean, min, max, etc.'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-09-20T18:41:27Z',
#   'updated_at': '2021-09-21T02:21:58Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43671',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43671',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43671.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43671.patch'},
#   'body': "- [ ] closes #15675\r\n- [ ] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [x] whatsnew entry\r\n\r\n@mzeitlin11 Any help you can provide on what tests I should add, or where to start digging for similar `GroupBy` tests would be appreciated. As stated in PR #41399, I'm not super familiar with Cython, so hoping that the previous contributors (stale) PR is close to what's needed (I suppose the tests will tell us).\r\n\r\nThanks!\r\n",
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43671/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43670',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43670/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43670/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43670/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43670',
#   'id': 1001266986,
#   'node_id': 'PR_kwDOAA0YD84r-k6W',
#   'number': 43670,
#   'title': 'ENH: latex styler bool pandas options',
#   'user': {'login': 'attack68',
#    'id': 24256554,
#    'node_id': 'MDQ6VXNlcjI0MjU2NTU0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24256554?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/attack68',
#    'html_url': 'https://github.com/attack68',
#    'followers_url': 'https://api.github.com/users/attack68/followers',
#    'following_url': 'https://api.github.com/users/attack68/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/attack68/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/attack68/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/attack68/subscriptions',
#    'organizations_url': 'https://api.github.com/users/attack68/orgs',
#    'repos_url': 'https://api.github.com/users/attack68/repos',
#    'events_url': 'https://api.github.com/users/attack68/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/attack68/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 35818298,
#     'node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#     'name': 'API Design',
#     'color': 'AD7FA8',
#     'default': False,
#     'description': None},
#    {'id': 251382258,
#     'node_id': 'MDU6TGFiZWwyNTEzODIyNTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20LaTeX',
#     'name': 'IO LaTeX',
#     'color': '006b75',
#     'default': False,
#     'description': 'to_latex'},
#    {'id': 1728592794,
#     'node_id': 'MDU6TGFiZWwxNzI4NTkyNzk0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Styler',
#     'name': 'Styler',
#     'color': '006b75',
#     'default': False,
#     'description': 'conditional formatting using DataFrame.style'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-20T18:25:46Z',
#   'updated_at': '2021-09-21T05:14:24Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43670',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43670',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43670.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43670.patch'},
#   'body': '- [x] adds the last  remaining options for #41395 for the existing args in Styler.to_latex.\r\n',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43670/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43669',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43669/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43669/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43669/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/43669',
#   'id': 1000829081,
#   'node_id': 'I_kwDOAA0YD847p3CZ',
#   'number': 43669,
#   'title': 'BUG: Wrong time data when using GMT+/-xy time zones',
#   'user': {'login': 'SKittan',
#    'id': 36617169,
#    'node_id': 'MDQ6VXNlcjM2NjE3MTY5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36617169?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SKittan',
#    'html_url': 'https://github.com/SKittan',
#    'followers_url': 'https://api.github.com/users/SKittan/followers',
#    'following_url': 'https://api.github.com/users/SKittan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/SKittan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/SKittan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/SKittan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/SKittan/orgs',
#    'repos_url': 'https://api.github.com/users/SKittan/repos',
#    'events_url': 'https://api.github.com/users/SKittan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/SKittan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-09-20T10:56:18Z',
#   'updated_at': '2021-09-20T17:33:57Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### \n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the master branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\npd.date_range("01.01.2021", periods=4, freq=\'H\', tz=\'Europe/Berlin\')\r\npd.date_range("01.01.2021", periods=4, freq=\'H\', tz=\'Etc/GMT+1\')\n```\n\n\n### Issue Description\n\nI use the date_range function to create a series of time values with time zone information. Since I don\'t want the DST, I do not use the Berlin time zone, but the equivalent GMT+1 zone. Comparing the results of both function calls, it seems that the time offset sign of the GMT is inverted. This leads to different results for above function calls, which is not correct in my opinion.\n\n### Expected Behavior\n\nI expect the same results for both function calls. But the time zone of GMT+1 is different from the time zone of Berlin.\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 73c68257545b5f8530b7044f56647bd2db92e2ba\r\npython           : 3.9.7.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19042\r\nmachine          : AMD64\r\nprocessor        : AMD64 Family 23 Model 1 Stepping 1, AuthenticAMD\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : de_DE.cp1252\r\n\r\npandas           : 1.3.3\r\nnumpy            : 1.20.3\r\npytz             : 2021.1\r\ndateutil         : 2.8.2\r\npip              : 21.2.4\r\nsetuptools       : 58.0.4\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.6.3\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.0.1\r\nIPython          : 7.27.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.4.3\r\nnumexpr          : 2.7.3\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.7.1\r\nsqlalchemy       : None\r\ntables           : 3.6.1\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : 0.54.0\r\n\r\n</details>\r\n',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43669/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43668',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43668/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43668/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43668/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/43668',
#   'id': 1000771074,
#   'node_id': 'I_kwDOAA0YD847po4C',
#   'number': 43668,
#   'title': "BUG: DataFrame.convert_dtypes doesn't preserve subclasses",
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 2559562239,
#     'node_id': 'MDU6TGFiZWwyNTU5NTYyMjM5',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Subclassing',
#     'name': 'Subclassing',
#     'color': 'abf98b',
#     'default': False,
#     'description': 'Subclassing pandas objects'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-20T09:49:31Z',
#   'updated_at': '2021-09-20T09:49:31Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "The `DataFrame.convert_dtypes` method returns the same dataframe (with potentially updated dtypes in certain columns), but because of the internal use of `concat`, it doesn't necessarily preserve the class type of the dataframe for subclasses.\r\n\r\nNoticed this in GeoPandas: https://github.com/geopandas/geopandas/issues/1870\r\n\r\nThis stems from the fact that the dataframe is basically decomposed into columns (Series), and then those are combined again into a DataFrame with `concat`. But at that point, you are concatting Series objects, and concat doesn't know anymore about the original dataframe class. Personally, I would say that the use of `concat` here is an implementation detail, and that `convert_dtypes` could easily preserve the original class of the calling dataframe.\r\n\r\nSmall reproducer without geopandas:\r\n\r\n```python\r\nclass SubclassedDataFrame(DataFrame):\r\n\r\n    @property\r\n    def _constructor(self):\r\n        return SubclassedDataFrame\r\n\r\n\r\nIn [51]: df = SubclassedDataFrame({'a': [1, 2, 3]})\r\n\r\nIn [52]: type(df)\r\nOut[52]: __main__.SubclassedDataFrame\r\n\r\nIn [53]: type(df.convert_dtypes())\r\nOut[53]: pandas.core.frame.DataFrame\r\n```\r\n\r\nNote I am not using `pd._testing.SubclassedDataFrame` since for this subclass, each column is also a SubclassesSeries, and then `concat` will actually preserve the subclass.",
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43668/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43667',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43667/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43667/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43667/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43667',
#   'id': 1000624132,
#   'node_id': 'PR_kwDOAA0YD84r8kI0',
#   'number': 43667,
#   'title': 'BUG: rename fails when using level',
#   'user': {'login': 'wojtek2kdev',
#    'id': 25926862,
#    'node_id': 'MDQ6VXNlcjI1OTI2ODYy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25926862?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wojtek2kdev',
#    'html_url': 'https://github.com/wojtek2kdev',
#    'followers_url': 'https://api.github.com/users/wojtek2kdev/followers',
#    'following_url': 'https://api.github.com/users/wojtek2kdev/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/wojtek2kdev/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/wojtek2kdev/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/wojtek2kdev/subscriptions',
#    'organizations_url': 'https://api.github.com/users/wojtek2kdev/orgs',
#    'repos_url': 'https://api.github.com/users/wojtek2kdev/repos',
#    'events_url': 'https://api.github.com/users/wojtek2kdev/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/wojtek2kdev/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 5,
#   'created_at': '2021-09-20T06:45:26Z',
#   'updated_at': '2021-09-21T03:26:51Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43667',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43667',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43667.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43667.patch'},
#   'body': '- [ ] closes #43659 \r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [x] whatsnew entry\r\n',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43667/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43666',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43666/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43666/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43666/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43666',
#   'id': 1000614729,
#   'node_id': 'PR_kwDOAA0YD84r8iX-',
#   'number': 43666,
#   'title': 'ENH: RangeIndex.sort_values now avoids materialization of values',
#   'user': {'login': 'usersblock',
#    'id': 12675558,
#    'node_id': 'MDQ6VXNlcjEyNjc1NTU4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12675558?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/usersblock',
#    'html_url': 'https://github.com/usersblock',
#    'followers_url': 'https://api.github.com/users/usersblock/followers',
#    'following_url': 'https://api.github.com/users/usersblock/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/usersblock/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/usersblock/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/usersblock/subscriptions',
#    'organizations_url': 'https://api.github.com/users/usersblock/orgs',
#    'repos_url': 'https://api.github.com/users/usersblock/repos',
#    'events_url': 'https://api.github.com/users/usersblock/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/usersblock/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 1218227310,
#     'node_id': 'MDU6TGFiZWwxMjE4MjI3MzEw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Index',
#     'name': 'Index',
#     'color': 'e99695',
#     'default': False,
#     'description': 'Related to the Index class or subclasses'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-09-20T06:25:54Z',
#   'updated_at': '2021-09-21T06:24:02Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43666',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43666',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43666.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43666.patch'},
#   'body': "- [x] closes #43584\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [x] whatsnew entry\r\nWhat's new: On any instance of RangeIndex, sort_values will not sort as it is already sorted.",
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43666/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43664',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43664/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43664/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43664/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/43664',
#   'id': 1000410828,
#   'node_id': 'I_kwDOAA0YD847oQ7M',
#   'number': 43664,
#   'title': 'TYP: Redundant imports to define the public API',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'mypy type annotations'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/32',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32/labels',
#    'id': 933188,
#    'node_id': 'MDk6TWlsZXN0b25lOTMzMTg4',
#    'number': 32,
#    'title': 'Contributions Welcome',
#    'description': 'Changes that would be nice to have in the next release. These issues are not blocking. They will be pushed to the next release if no one has time to fix them.',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 1076,
#    'closed_issues': 777,
#    'state': 'open',
#    'created_at': '2015-01-13T10:53:19Z',
#    'updated_at': '2021-09-20T14:58:22Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-09-19T20:25:24Z',
#   'updated_at': '2021-09-20T09:28:10Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
# ...
#    {'id': 251382258,
#     'node_id': 'MDU6TGFiZWwyNTEzODIyNTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20LaTeX',
#     'name': 'IO LaTeX',
#     'color': '006b75',
#     'default': False,
#     'description': 'to_latex'},
#    {'id': 1728592794,
#     'node_id': 'MDU6TGFiZWwxNzI4NTkyNzk0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Styler',
#     'name': 'Styler',
#     'color': '006b75',
#     'default': False,
#     'description': 'conditional formatting using DataFrame.style'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-18T20:45:11Z',
#   'updated_at': '2021-09-20T18:30:57Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43649',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43649',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43649.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43649.patch'},
#   'body': "- [x] closes #43637 #43644\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [x] <s>whatsnew entry</s> not needed?\r\n\r\nThe key change made here was to add a single line: `if r not in self.hidden_rows: (line 500)` in the loop.\r\nGithub makes it look like there are a lot more changes.\r\n\r\n`_translate_latex` then needed updating due to the different generation of the object that is input to it.\r\n\r\nAnd tests were update and comprehensive tests for the issues added.\r\n\r\nAlso **closes** the prs #43638  #43640.\r\n\r\nI don't think this requires a whatsnew since the bug seems to have been created by hiding `levels` which is a new feature in 1.4.0.",
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43649/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43648',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43648/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43648/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43648/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/43648',
#   'id': 1000122295,
#   'node_id': 'I_kwDOAA0YD847nKe3',
#   'number': 43648,
#   'title': 'BUG: latex css conversion does not work on new applymap_index',
#   'user': {'login': 'attack68',
#    'id': 24256554,
#    'node_id': 'MDQ6VXNlcjI0MjU2NTU0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24256554?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/attack68',
#    'html_url': 'https://github.com/attack68',
#    'followers_url': 'https://api.github.com/users/attack68/followers',
#    'following_url': 'https://api.github.com/users/attack68/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/attack68/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/attack68/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/attack68/subscriptions',
#    'organizations_url': 'https://api.github.com/users/attack68/orgs',
#    'repos_url': 'https://api.github.com/users/attack68/repos',
#    'events_url': 'https://api.github.com/users/attack68/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/attack68/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 251382258,
#     'node_id': 'MDU6TGFiZWwyNTEzODIyNTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20LaTeX',
#     'name': 'IO LaTeX',
#     'color': '006b75',
#     'default': False,
#     'description': 'to_latex'},
#    {'id': 1728592794,
#     'node_id': 'MDU6TGFiZWwxNzI4NTkyNzk0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Styler',
#     'name': 'Styler',
#     'color': '006b75',
#     'default': False,
#     'description': 'conditional formatting using DataFrame.style'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-18T20:05:49Z',
#   'updated_at': '2021-09-19T19:45:18Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### \n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the master branch of pandas.\n\n\n### Reproducible Example\n\n```python\ndf = DataFrame([[0], [1]], index=[0, 1])\r\nstyler = df.style\r\nstyler.applymap(lambda x: "color: red;" if x == 0 else "")\r\nstyler.applymap_index(lambda x: "color: blue;" if x == 0 else "")\r\nprint(styler.to_latex(convert_css=True))\r\n\r\n\\begin{tabular}{lr}\r\n & 0 \\\\\r\n\\colorblue 0 & \\color{red} 0 \\\\\r\n1 & 1 \\\\\r\n\\end{tabular}\n```\n\n\n### Issue Description\n\nthe new method applymap_index has not been hooked up to the CSS conversion for styler.to_latex.\n\n### Expected Behavior\n\nshould convert to `color{blue}`\n\n### Installed Versions\n\nmaster',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43648/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43647',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43647/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43647/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43647/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/43647',
#   'id': 1000115023,
#   'node_id': 'PR_kwDOAA0YD84r7Qwj',
#   'number': 43647,
#   'title': "BUG: REGR: read_csv with memory_map=True raises UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc4 in position 262143: unexpected end of data ",
#   'user': {'login': 'michal-gh',
#    'id': 9954897,
#    'node_id': 'MDQ6VXNlcjk5NTQ4OTc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9954897?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/michal-gh',
#    'html_url': 'https://github.com/michal-gh',
#    'followers_url': 'https://api.github.com/users/michal-gh/followers',
#    'following_url': 'https://api.github.com/users/michal-gh/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/michal-gh/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/michal-gh/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/michal-gh/subscriptions',
#    'organizations_url': 'https://api.github.com/users/michal-gh/orgs',
#    'repos_url': 'https://api.github.com/users/michal-gh/repos',
#    'events_url': 'https://api.github.com/users/michal-gh/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/michal-gh/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'},
#    {'id': 47229171,
#     'node_id': 'MDU6TGFiZWw0NzIyOTE3MQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20CSV',
#     'name': 'IO CSV',
#     'color': '5319e7',
#     'default': False,
#     'description': 'read_csv, to_csv'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/90',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/90',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/90/labels',
#    'id': 7142224,
#    'node_id': 'MI_kwDOAA0YD84AbPtQ',
#    'number': 90,
#    'title': '1.3.4',
#    'description': 'on-merge: backport to 1.3.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 40,
#    'closed_issues': 25,
#    'state': 'open',
#    'created_at': '2021-09-10T19:48:56Z',
#    'updated_at': '2021-09-20T16:02:51Z',
#    'due_on': '2021-10-17T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-09-18T19:29:29Z',
#   'updated_at': '2021-09-20T16:03:49Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/43647',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/43647',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/43647.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/43647.patch'},
#   'body': '- [x ] closes #43540 \r\n- [x ] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [x ] whatsnew entry\r\n',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43647/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43644',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43644/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43644/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43644/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/43644',
#   'id': 1000092558,
#   'node_id': 'I_kwDOAA0YD847nDOO',
#   'number': 43644,
#   'title': 'BUG: styler hide_index hide_columns misaligns multiindex',
#   'user': {'login': 'attack68',
#    'id': 24256554,
#    'node_id': 'MDQ6VXNlcjI0MjU2NTU0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24256554?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/attack68',
#    'html_url': 'https://github.com/attack68',
#    'followers_url': 'https://api.github.com/users/attack68/followers',
#    'following_url': 'https://api.github.com/users/attack68/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/attack68/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/attack68/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/attack68/subscriptions',
#    'organizations_url': 'https://api.github.com/users/attack68/orgs',
#    'repos_url': 'https://api.github.com/users/attack68/repos',
#    'events_url': 'https://api.github.com/users/attack68/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/attack68/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 57395487,
#     'node_id': 'MDU6TGFiZWw1NzM5NTQ4Nw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20HTML',
#     'name': 'IO HTML',
#     'color': '006b75',
#     'default': False,
#     'description': 'read_html, to_html, Styler.apply, Styler.applymap'},
#    {'id': 251382258,
#     'node_id': 'MDU6TGFiZWwyNTEzODIyNTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20LaTeX',
#     'name': 'IO LaTeX',
#     'color': '006b75',
#     'default': False,
#     'description': 'to_latex'},
#    {'id': 1728592794,
#     'node_id': 'MDU6TGFiZWwxNzI4NTkyNzk0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Styler',
#     'name': 'Styler',
#     'color': '006b75',
#     'default': False,
#     'description': 'conditional formatting using DataFrame.style'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-18T17:44:49Z',
#   'updated_at': '2021-09-19T19:45:48Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### \n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the master branch of pandas.\n\n\n### Reproducible Example\n\n```python\nmidx = MultiIndex.from_product([["A", "B"], ["a", "b"], ["X", "Y"]], names=["zero", "one", "two"])\r\ncidx = MultiIndex.from_product([["a", "b"], ["C", "D"], ["V", "W"]], names=["zero", "one", "two"])\r\ndf = DataFrame(np.arange(64).reshape(8,8), index=midx, columns=cidx)\r\nstyler = Styler(df)\r\nstyler.hide_index(level=1).hide_columns(level=0)\r\nstyler.hide_index([("A", "a", "X"), ("A", "b", "X")])\r\nstyler.hide_columns([("a", "C", "W"), ("a", "D", "V")])\r\nstyler\n```\n\n\n### Issue Description\n\nWhen using a MultiIndex and combining with hiding different levels and hiding specific rows/columns, some bugs appear.\r\n\r\nOutput is quite strange on second row for HTML output.\r\n\r\n![Screen Shot 2021-09-18 at 19 40 34](https://user-images.githubusercontent.com/24256554/133897657-0e500e82-d1ae-4098-9d19-c194dbcc58fc.png)\r\n\r\nAlso using LaTeX output:  \r\n```\r\n>>> styler.to_latex()\r\n\\begin{tabular}{llrrrrrr}\r\n & one & C & D & \\multicolumn{2}{r}{C} & \\multicolumn{2}{r}{D} \\\\\r\n & two & V & W & V & W & V & W \\\\\r\nzero & two &  &  &  &  &  &  \\\\\r\n\\multirow[c]{2}{*}{A} &  & Y & 8 & 11 & 12 & 13 & 14 & 15 \\\\\r\n &  & Y & 24 & 27 & 28 & 29 & 30 & 31 \\\\\r\n\\multirow[c]{4}{*}{B} & \\multirow[c]{2}{*}{} & X & 32 & 35 & 36 & 37 & 38 & 39 \\\\\r\n &  & Y & 40 & 43 & 44 & 45 & 46 & 47 \\\\\r\n & \\multirow[c]{2}{*}{} & X & 48 & 51 & 52 & 53 & 54 & 55 \\\\\r\n &  & Y & 56 & 59 & 60 & 61 & 62 & 63 \\\\\r\n\\end{tabular}\r\n```\r\n\r\nThe above is a LaTeX error but if the number of columns is expanded to 9 then it renders like:\r\n![Screen Shot 2021-09-18 at 19 43 51](https://user-images.githubusercontent.com/24256554/133897745-30a2eb1c-80e3-4e7c-8bd7-c3765ef973f6.png)\r\n\r\n\n\n### Expected Behavior\n\nClearly we want to align all the datapoints and have the hidden levels correctly hidden.\n\n### Installed Versions\n\nmaster\r\n',
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/43644/timeline',
#   'performed_via_github_app': None}]

# %%
import pandas as pd
issues=pd.DataFrame(data,columns=['number','title','labels','state'])
issues
# Out:
#     number                                              title  \
# 0    43679            REF: unify i8 casting in DatetimeEngine
# 1    43678                        POC: New UDF methods option
# 2    43677                        CI: Strict channel Priority
# 3    43675                 PERF: Groupby.any/all object dtype
# 4    43674                                           GH 38815
# 5    43673  ENH: omit CSSStyle rules for hidden table elem...
# 6    43672                                    CI: run pyright
# 7    43671        ENH: enable skipna on groupby reduction ops
# 8    43670              ENH: latex styler bool pandas options
# 9    43669  BUG: Wrong time data when using GMT+/-xy time ...
# 10   43668  BUG: DataFrame.convert_dtypes doesn't preserve...
# 11   43667                 BUG: rename fails when using level
# 12   43666  ENH: RangeIndex.sort_values now avoids materia...
# 13   43664    TYP: Redundant imports to define the public API
# 14   43663                         ENH: Add Inner Fill Option
# 15   43662      ENH: `Styler.bar` accepts matplotlib colormap
# 16   43660                         CI: adding cython coverage
# 17   43659                 BUG: rename fails when using level
# 18   43658              DEPR: Fix deprecation warnings in ASV
# 19   43657  BUG: add css conversion for new `Styler.apply_...
# 20   43656      DOC: expand allowed vals for `multicol_align`
# 21   43654                                  PERF: sparse take
# 22   43653  REF: ExtensionIndex.searchsorted -> IndexOpsMi...
# 23   43652                          CI: codecov for pyx files
# 24   43651                         REF: remove JoinUnit.shape
# 25   43650                  CI/BUG: pyarrow read_csv deadlock
# 26   43649  BUG: styler multiindex hiding indexes and colu...
# 27   43648  BUG: latex css conversion does not work on new...
# 28   43647  BUG: REGR: read_csv with memory_map=True raise...
# 29   43644  BUG: styler hide_index hide_columns misaligns ...
#
#                                                labels state
# 0                                                  []  open
# 1   [{'id': 35818298, 'node_id': 'MDU6TGFiZWwzNTgx...  open
# 2                                                  []  open
# 3                                                  []  open
# 4                                                  []  open
# 5   [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 6                                                  []  open
# 7   [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 8   [{'id': 35818298, 'node_id': 'MDU6TGFiZWwzNTgx...  open
# 9   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 10  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 11                                                 []  open
# 12  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 13  [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 14  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 15  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 16                                                 []  open
# 17  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 18  [{'id': 87485152, 'node_id': 'MDU6TGFiZWw4NzQ4...  open
# 19  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 20  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 21  [{'id': 2822098, 'node_id': 'MDU6TGFiZWwyODIyM...  open
# 22                                                 []  open
# 23  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 24                                                 []  open
# 25  [{'id': 127685, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 26  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 27  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 28  [{'id': 32815646, 'node_id': 'MDU6TGFiZWwzMjgx...  open
# 29  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
